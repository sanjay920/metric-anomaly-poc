# %%
import pandas as pd
from prophet import Prophet
from datetime import datetime, timedelta
from collections import deque
import numpy as np
import math
import time
import altair as alt
#from neuralprophet import NeuralProphet

import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

from orbit.utils.simulation import make_trend, make_seasonality, make_regression

plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = [8, 8]

# %matplotlib inline

import pandas as pd
import random
random.seed()

myfreq = "D" # "D" or "1MIN"
if myfreq == "1MIN":
    xs = pd.date_range("00:00", "23:59", freq=myfreq)
else:
    xs = pd.date_range(start='1/1/2018', end='1/1/2022', freq=myfreq)
xs
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2021-12-23', '2021-12-24', '2021-12-25', '2021-12-26',
#                '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2021-12-31', '2022-01-01'],
#               dtype='datetime64[ns]', length=1462, freq='D')

# %%
def detect_anomalies(forecast):
    forecasted = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'fact']].copy()
    #forecast['fact'] = df['y']
    forecasted['anomaly'] = 0
    forecasted.loc[forecasted['fact'] > forecasted['yhat_upper'], 'anomaly'] = 1
    forecasted.loc[forecasted['fact'] < forecasted['yhat_lower'], 'anomaly'] = 1

    #anomaly importances
    '''
    forecasted['importance'] = 0
    forecasted.loc[forecasted['anomaly'] ==1, 'importance'] = \
        (forecasted['fact'] - forecasted['yhat_upper'])/forecast['fact']
    forecasted.loc[forecasted['anomaly'] == 1, 'importance'] = \
        (forecasted['yhat_lower'] - forecasted['fact'])/forecast['fact']
    '''
    
    return forecasted
def plot_anomalies(forecasted, mytitle='Anomaly Detection'):
    interval = alt.Chart(forecasted).mark_area(interpolate="basis", color = '#7FC97F').encode(
    x=alt.X('ds:T', axis=alt.Axis(format='%H:%M'), title ='date'),
    y='yhat_upper',
    y2='yhat_lower',
    tooltip=['ds', 'fact', 'yhat_lower', 'yhat_upper']
    ).interactive().properties(
        title=mytitle
    )

    fact = alt.Chart(forecasted[forecasted.anomaly==0]).mark_circle(size=15, opacity=0.7, color = 'Black').encode(
        x='ds:T',
        y=alt.Y('fact', title='CPU Utilization Percentage'),    
        tooltip=['ds', 'fact', 'yhat_lower', 'yhat_upper']
    ).interactive()

    anomalies = alt.Chart(forecasted[forecasted.anomaly!=0]).mark_circle(size=30, color = 'Red').encode(
        x='ds:T',
        y=alt.Y('fact', title='CPU Utilization Percentage'),    
        tooltip=['ds', 'fact', 'yhat_lower', 'yhat_upper']
    ).interactive()

    return alt.layer(interval, fact, anomalies)\
              .properties(width=870, height=450)\
              .configure_title(fontSize=20)

# %%
## generate random data

multiplier = 10

## random walk
# rw = make_trend(len(xs), rw_loc=0.01, rw_scale=1, seed=random.randint(1, 2000))
# # normalize [0, 1.5]
# y= 1 + (multiplier*(rw - np.min(rw))/np.ptp(rw))
# _ = plt.plot(xs, y)

## fourier
# fs = make_seasonality(len(xs), seasonality=random.randint(100, 1000), method='fourier', order=random.randint(4, 10), seed=random.randint(1, 2000))
# y = 1 + (multiplier*(fs - np.min(fs))/np.ptp(fs))
# _ = plt.plot(y)

# arma
arma_trend =  make_trend(len(xs), method='arma', arma=[.8, -.1], seed=random.randint(1, 2000))
# normalize [0, 1.5]
y = (multiplier*(arma_trend - np.min(arma_trend))/np.ptp(arma_trend))
_ = plt.plot(xs, y)

# # discrete
# ds = make_seasonality(len(xs), seasonality=random.randint(20, 50), duration=random.randint(2, 50), method='discrete', seed=random.randint(1, 2000))
# y = (multiplier*(ds - np.min(ds))/np.ptp(ds))
# _ = plt.plot(xs, y)

df = pd.DataFrame({"ds" : xs, "y" : y})

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %matplotlib inline
mydf = pd.Series(y, xs)

## shared parameters among different models

max_interval = 1440 # max training time interval
one_step_len = 5 ## re-fit model every five steps
n_loops = (len(mydf) // one_step_len) - 1
confidence_interval_level = 3 ## 1 for 68%, 2 for 95% and 3 standard deviation for 99.7%. use 3 or 2

# %%
## SARIMAX model fit

from statsmodels.tsa.statespace.sarimax import SARIMAX
import statsmodels as sm
# mydf2, mytest = mydf[:1000], mydf[1000:1010]
# model = SARIMAX(mydf2, order=(1,1,1))
# model_fit = model.fit(disp=0)
# res = model_fit.get_forecast(10, alpha=0.05)
# res.conf_int()
# res1 = model_fit.forecast(10, alpha=0.05)
# res1
# fc_series = pd.Series(fc, index=mytest.index)
# lower_series = pd.Series(conf[:, 0], index=mytest.index)
# upper_series = pd.Series(conf[:, 1], index=mytest.index)

print(n_loops)
fcall = None
lowerall = None
upperall = None

for i1 in range(10, n_loops): # 39 for normal period and 59 for all
    i = i1 * one_step_len
    mydf1, mytest = mydf[0:i+one_step_len].copy(), mydf[i+one_step_len: i + one_step_len*2].copy() # no max interval
    order = (1,1,1)
    seasonal_order= (0,0,0,0)
    enforce_stationarity = True
    myfit = SARIMAX(mydf1,enforce_stationarity=enforce_stationarity, order=order, seasonal_order=seasonal_order).fit(disp=False)

    alpha = 0.003 if confidence_interval_level == 3 else 0.05 if confidence_interval_level == 2 else 0.32
    fc_series = myfit.forecast(one_step_len)
    intervals = myfit.get_forecast(one_step_len).conf_int(alpha=alpha)
    lower_series, upper_series = intervals["lower y"], intervals["upper y"]
    
    if fcall is None:
        fcall = fc_series.copy()
        lowerall = lower_series.copy()
        upperall = upper_series.copy()
    else:
        fcall = pd.concat([fcall, fc_series.copy()])
        lowerall = pd.concat([lowerall, lower_series.copy()])
        upperall = pd.concat([upperall, upper_series.copy()])
# Out:
# 291

# %%
## plot SARIMAX

tf1 = pd.DataFrame({"ds" : mydf.index, "yhat" : fcall, "yhat_lower" : lowerall, "yhat_upper" : upperall, "fact" : mydf})
detected_anomalies = detect_anomalies(tf1)
plot_anomalies(detected_anomalies, mytitle="SARIMAX Anomaly Detection")
# Out:
# alt.LayerChart(...)

# %%
## Holt-Winters Exponential Smoothing model fit

print(n_loops)
total_forecast = None
mses = []
fcast_total2 = None
fcast_upper = None
fcast_lower = None

for i1 in range(10, n_loops): # 39 for normal period and 59 for all
    i = i1 * one_step_len
    mydf1, df_val1 = mydf[0:i+one_step_len].copy(), mydf[i+one_step_len: i + one_step_len*2].copy().reset_index() # no max interval
    fit2 = Holt(mydf1, initialization_method="estimated").fit()
    fcast2 = fit2.forecast(one_step_len).rename("Holt's")
      
#     fit2 = ExponentialSmoothing(
#     mydf1,
#     seasonal_periods=365,
#     trend="add",
#     seasonal="add",
#     damped_trend=True,
#     use_boxcox=True,
#     initialization_method="estimated",
#     ).fit()
#     fcast2 = fit2.forecast(one_step_len).rename("Holt-Winters (add-mul-seasonal)")

    
#     fit2 = Holt(mydf1, exponential=True, initialization_method="estimated").fit()
#     fcast2 = fit2.forecast(one_step_len).rename("Exponential")

#     fit2 = Holt(mydf1, damped_trend=True, initialization_method="estimated").fit(
#         damping_trend=0.98
#     )
#     fcast2 = fit2.forecast(one_step_len).rename("Additive Damped")
    
#     fit2 = Holt(
#         mydf1, exponential=True, damped_trend=True, initialization_method="estimated"
#     ).fit()
#     fcast2 = fit2.forecast(one_step_len).rename("Multiplicative Damped")
    
    std2 = confidence_interval_level * np.sqrt(fit2.sse / len(mydf1))
    fcast2lower = fcast2 - std2
    fcast2upper = fcast2 + std2
    fcast2lower, fcast2upper
    if fcast_total2 is None:
        fcast_total2 = fcast2.copy()
        fcast_lower = fcast2lower.copy()
        fcast_upper = fcast2upper.copy()
    else:
        fcast_total2 = pd.concat([fcast_total2, fcast2.copy()])
        fcast_lower = pd.concat([fcast_lower, fcast2lower.copy()])
        fcast_upper = pd.concat([fcast_upper, fcast2upper.copy()])
        
    
# plt.figure(figsize=(12, 8))
# plt.plot(mydf, marker="o", color="black")
# plt.plot(fcast_total2, color="blue")
# plt.plot(fcast_upper, color="red")
# plt.plot(fcast_lower, color="green")
# plt.show()
# Out:
# 291
# /Users/tybalex/.pyenv/versions/3.8.6/envs/py38/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:132: FutureWarning: The 'freq' argument in Timestamp is deprecated and will be removed in a future version.
#   date_key = Timestamp(key, freq=base_index.freq)

# %%
## plot results
total_forecast = pd.DataFrame({"ds" : mydf.index, "yhat" : fcast_total2, "yhat_lower" : fcast_lower, "yhat_upper" : fcast_upper, "fact" : mydf})
detected_anomalies = detect_anomalies(total_forecast)
plot_anomalies(detected_anomalies, mytitle="Holt-Winters Anomaly Detection")
# Out:
# alt.LayerChart(...)

# %%
## Facebook Prophet model fit
print(n_loops)
total_forecast = None
mses = []
max_val = multiplier 
max_interval=600 ##for fb prophet, the max interval needs to be a smaller number
growth = "linear" # logistic or linear or flat?  ## linear seems to be more stable

for i1 in range(20, n_loops): # 39 for normal period and 59 for all
    i = i1 * one_step_len
    df_train1, df_val1 = df[0:i+one_step_len].copy(), df[i+one_step_len: i + one_step_len*2].copy().reset_index() # no max interval
    lb = 0 if i1 == n_loops-1 else max(0, i + one_step_len - max_interval)
    df_train1, df_val1 = df[lb:i+one_step_len].copy(), df[i+one_step_len: i + one_step_len*2].copy().reset_index()
    fact_values = list(df_val1['y'].values)
    
    if growth == "logistic":
        df_train1['cap'], df_val1['cap'] = max_val, max_val
        df_train1['floor'], df_val1['floor'] = 0.0, 0.0
    pm = Prophet(growth=growth,
    yearly_seasonality=False, 
    weekly_seasonality=False,
    daily_seasonality=False,
    changepoint_prior_scale=0.1,
    interval_width=(0.997 if confidence_interval_level==3 else 0.95 if confidence_interval_level==2 else 0.68),        
    ) # need to add min_seasonality
    #pm = pm.add_seasonality(name='half_daily', period=500, fourier_order=10) ## tuneable value: period (unit: day), fourier_order: 
    #pm = pm.add_seasonality(name='hourly', period=0.1, fourier_order=10)
    pm.fit(df_train1)   
    future = pm.make_future_dataframe(periods=one_step_len,freq=myfreq,include_history=False,)
    future["cap"] = max_val
    future["floor"] = 0.0
    future_forecast = pm.predict(future)
    #future_forecast = future_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper', 'trend']]
        
        
    future_forecast['fact'] = fact_values
    
#     mse = sum([(f-p) * (f-p) for f,p in zip(fact_values, predicted_values)]) / len(fact_values)
#     mses.append(mse)
#     future_forecast['yhat_upper'] = updated_upper_stds
#     future_forecast['yhat_lower'] = updated_lower_stds
    #future_forecast['y'] = df_val1['y']
    #pm.plot(future_forecast)
    if total_forecast is None:
        total_forecast = future_forecast.copy()
    else:
        total_forecast = pd.concat([total_forecast,future_forecast.copy()])
total_forecast = total_forecast.reset_index()
# Out:
# 291
# Initial log joint probability = -6.23736
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       142.556   1.06166e-07       29.4649      0.1276           1      152
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       142.556   5.56839e-06       25.0981   1.619e-07       0.001      197  LS failed, Hessian reset
#      118       142.557   1.16467e-06       28.4344   4.388e-08       0.001      250  LS failed, Hessian reset
#      125       142.557   1.94155e-08       28.6979       0.413           1      262
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.44217
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       150.256   4.63771e-05       27.5983           1           1      142
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      161       150.317   0.000996777       38.2879   3.141e-05       0.001      263  LS failed, Hessian reset
#      199       150.334   1.15253e-05       30.6634           1           1      322
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      213       150.337   3.54944e-05       20.0937   8.986e-07       0.001      376  LS failed, Hessian reset
#      249       150.338   9.42973e-10       38.7574   0.0008833           1      431
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -3.80109
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       39       158.477   0.000355686       30.9014   1.595e-05       0.001       91  LS failed, Hessian reset
#       56       158.483   5.45914e-05        33.548   1.546e-06       0.001      143  LS failed, Hessian reset
#       99       158.485   1.88652e-06       30.9179           1           1      214
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117       158.491   0.000100283       21.2851   2.618e-06       0.001      284  LS failed, Hessian reset
#      149       158.492   5.44004e-06       21.2068    1.47e-07       0.001      366  LS failed, Hessian reset
#      181       158.492     1.421e-08       25.1942      0.5541      0.5541      413
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -3.90932
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       162.652   5.58524e-07        29.082      0.2555      0.2555      146
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      122       162.652   7.29914e-09       31.8421      0.2717      0.2717      177
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -4.13499
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59         171.3   1.42439e-08       28.9643      0.2614      0.8959       87
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.0986
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       95       179.021   2.47646e-06       36.4539   6.985e-08       0.001      168  LS failed, Hessian reset
#       99       179.021   7.00295e-07       30.2282       2.094      0.7431      174
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117       179.021   1.35139e-08       34.2237      0.4046           1      197
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.64196
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       55       186.329    0.00146704       32.1384    3.35e-05       0.001      113  LS failed, Hessian reset
#       99       186.349   1.17288e-07       32.6888      0.3134      0.3134      172
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       186.349   3.75831e-07        34.674   1.087e-08       0.001      219  LS failed, Hessian reset
#      122       186.349   2.62322e-08       32.9729       1.604      0.1604      242
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.04904
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       195.764   9.93655e-05       29.2485           1           1      144
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      183       195.777   2.15425e-05       39.5604   5.357e-07       0.001      295  LS failed, Hessian reset
#      199       195.777   7.36017e-07       28.1462           1           1      324
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      230       195.777   3.21639e-09       34.2435     0.02884       0.619      373
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -4.60895
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        204.64   1.65981e-05       30.5893      0.2322      0.2322      144
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       204.662   0.000227286       40.9048   6.271e-06       0.001      196  LS failed, Hessian reset
#      142       204.664    6.3569e-06        25.384    1.56e-07       0.001      275  LS failed, Hessian reset
#      167       204.664   7.97307e-09       22.5987      0.1098      0.1098      310
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -5.91565
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       76       207.841   1.18641e-05       33.3032   3.188e-07       0.001      143  LS failed, Hessian reset
#       97       207.842    5.3239e-07       30.9561   1.428e-08       0.001      210  LS failed, Hessian reset
#       99       207.842   1.36938e-07       33.7974      0.8999      0.8999      212
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      111       207.842   2.42501e-08       33.2913      0.1294      0.6407      228
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.24923
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       76       213.137   1.48524e-05       40.9883   4.464e-07       0.001      148  LS failed, Hessian reset
#       99       213.137   6.73958e-07       37.5634           1           1      178
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      114       213.137   8.70323e-09       37.1196      0.4028      0.4028      197
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -8.73474
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       57       221.313    0.00491097          71.1   7.256e-05       0.001      106  LS failed, Hessian reset
#       99       221.563   4.85882e-06       41.1397      0.5591      0.5591      158
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      157       221.857   1.39103e-08       33.5015      0.2876           1      245
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.13784
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       65       228.731   0.000164984       39.2739   5.018e-06       0.001      133  LS failed, Hessian reset
#       99       228.736   3.64501e-08       37.1226      0.7267      0.7267      182
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      100       228.736   2.31395e-08       35.9658      0.2244      0.8157      184
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.44918
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       54        237.54   0.000963288       37.6062   2.335e-05       0.001      122  LS failed, Hessian reset
#       81       237.564   3.37261e-05       37.6078   8.662e-07       0.001      188  LS failed, Hessian reset
#       99       237.564   5.11558e-07       30.4534      0.3906      0.3906      215
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       237.564   7.35785e-07       30.0018   1.933e-08       0.001      283  LS failed, Hessian reset
#      131       237.564   5.46455e-09       35.1802      0.1404      0.1404      304
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -4.65373
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       245.302   4.94513e-07       38.9483      0.3968           1      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      105       245.302   1.21266e-06       36.3825   3.546e-08       0.001      170  LS failed, Hessian reset
#      118       245.302   2.20133e-08        33.322           1           1      189
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.48363
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       41       253.228   0.000283937       37.1764   6.629e-06       0.001       97  LS failed, Hessian reset
#       99       253.245   0.000222455       37.7293           1           1      173
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      106       253.261   0.000762324       41.3832   1.487e-05       0.001      239  LS failed, Hessian reset
#      162       253.287     4.503e-07       40.7853   1.063e-08       0.001      352  LS failed, Hessian reset
#      171       253.287   8.55947e-09       36.7115      0.1771      0.1771      367
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -6.7319
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       261.864   1.15298e-07       46.6914           1           1      138
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       261.864   7.48296e-09       49.6646      0.2002       0.729      148
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -4.65177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59       270.385   0.000722098       38.4512   1.732e-05       0.001      118  LS failed, Hessian reset
#       99        270.41   2.71067e-07       42.1529      0.4867      0.4867      177
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117        270.41   1.33469e-08       39.0984      0.5445      0.5445      202
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.61881
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       74       279.359   0.000238258       39.6424   5.749e-06       0.001      137  LS failed, Hessian reset
#       99       279.371   4.65978e-07       39.0511      0.4756      0.4756      169
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      121       279.371   1.27133e-08       45.1009      0.2747           1      208
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.63119
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       40       288.318   0.000291168       33.6217   7.008e-06       0.001       87  LS failed, Hessian reset
#       80       288.362   0.000428813       36.3517   9.803e-06       0.001      181  LS failed, Hessian reset
#       98        288.38   4.83621e-05       41.7928   1.175e-06       0.001      240  LS failed, Hessian reset
#       99       288.381    2.3197e-05       38.1429           1           1      241
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      128       288.381   5.39888e-07       41.1997   1.355e-08       0.001      317  LS failed, Hessian reset
#      139       288.382   1.71294e-08       38.1939      0.2588           1      335
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.40764
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       53       292.524   0.000255283       26.4271   1.028e-05       0.001      113  LS failed, Hessian reset
#       98       292.633    0.00117797       32.4826   2.965e-05       0.001      210  LS failed, Hessian reset
#       99       292.635   0.000465811       38.3416           1           1      211
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      157       292.745    0.00130938       33.7271   4.507e-05       0.001      317  LS failed, Hessian reset
#      199       292.821   1.95398e-05       36.2652           1           1      368
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      224       292.832   5.38792e-05       40.8925   1.515e-06       0.001      434  LS failed, Hessian reset
#      294       292.836   4.46188e-05       46.5959   1.269e-06       0.001      569  LS failed, Hessian reset
#      299       292.837   9.83305e-06       28.2284           1           1      575
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      380       292.848   0.000126012       35.5805   2.902e-06       0.001      730  LS failed, Hessian reset
#      399       292.857   3.80973e-05        35.169           1           1      753
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      432       292.859    1.5606e-05       32.0104   5.155e-07       0.001      834  LS failed, Hessian reset
#      482        292.86   2.38241e-05       34.8023    5.77e-07       0.001      941  LS failed, Hessian reset
#      499       292.861   1.47439e-06       35.6707       2.285      0.7781      969
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      530       292.861   2.34828e-07       37.7849    5.69e-09       0.001     1049  LS failed, Hessian reset
#      535       292.861   1.08934e-08       29.8814       0.154      0.5271     1056
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.83188
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       56       300.728   0.000226228       30.9372    8.66e-06       0.001      111  LS failed, Hessian reset
#       99       300.733   5.22004e-05       26.6636           1           1      171
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115        300.76     0.0010136       32.0375   3.044e-05       0.001      260  LS failed, Hessian reset
#      185       300.784   3.62685e-08       27.5027      0.4281      0.4281      364
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.24184
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       62       309.519   2.01709e-05       33.1486   6.363e-07       0.001      126  LS failed, Hessian reset
#       99        309.52    8.2397e-07        22.749           1           1      175
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      125        309.52   9.99637e-07       34.0954   2.321e-08       0.001      245  LS failed, Hessian reset
#      138        309.52   1.88466e-08       28.4707      0.3511           1      261
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -4.83193
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       48       317.946   0.000463602       36.3934   9.924e-06       0.001      102  LS failed, Hessian reset
#       89       317.968   3.80204e-05       26.8673   1.018e-06       0.001      190  LS failed, Hessian reset
#       99       317.969   4.98585e-06       37.1259           1           1      203
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      134       317.969     2.647e-06       42.5632   7.206e-08       0.001      283  LS failed, Hessian reset
#      168        317.97   4.89603e-08       29.4672      0.2626           1      332
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.67064
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63       321.741    0.00208888       30.2272   5.703e-05       0.001      119  LS failed, Hessian reset
#       99       321.788   0.000230506       38.5224           1           1      167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       321.908     0.0022982       30.7345   6.814e-05       0.001      212  LS failed, Hessian reset
#      199       322.088    0.00359104       39.6291           1           1      340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      207       322.161    0.00201558       35.8244   4.963e-05       0.001      393  LS failed, Hessian reset
#      246       322.281   0.000246279       38.7528   6.451e-06       0.001      484  LS failed, Hessian reset
#      293       322.287   2.03505e-05       35.1303   4.956e-07       0.001      594  LS failed, Hessian reset
#      299       322.288   1.12412e-06       25.5983     0.05967           1      602
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      378       322.292   6.93383e-05       35.0881   1.606e-06       0.001      732  LS failed, Hessian reset
#      399       322.294   5.54462e-06        40.023       0.512       0.512      760
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      439       322.295   1.56854e-08       23.9794     0.04954           1      822
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.61985
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       87       323.077    0.00135578       22.2817   4.112e-05       0.001      155  LS failed, Hessian reset
#       99       323.102   3.07105e-05       24.6683      0.3409      0.3409      170
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      117       323.104   1.55073e-05       31.4085   4.718e-07       0.001      237  LS failed, Hessian reset
#      155       323.111   0.000122945       36.1258   3.539e-06       0.001      334  LS failed, Hessian reset
#      182       323.113   6.87705e-06       34.5318   2.468e-07       0.001      402  LS failed, Hessian reset
#      199       323.114   1.27824e-07       27.5978           1           1      430
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      210       323.114   2.22478e-08       26.8821      0.0639           1      444
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.48357
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       59       332.042    0.00743139       36.3559   0.0002117       0.001      128  LS failed, Hessian reset
#       99        332.18    0.00106131       38.5917      0.1069           1      199
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      138       332.233   0.000849469       33.0231   3.467e-05       0.001      330  LS failed, Hessian reset
#      199       332.282   2.93895e-06       28.0597      0.9561      0.9561      417
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      239       332.365     0.0003387       38.4896       9e-06       0.001      501  LS failed, Hessian reset
#      299       332.416   2.22696e-07       30.7249           1           1      586
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       332.713     0.0005916       32.2281       0.373      0.0373      720
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      485       332.885    7.2988e-05       25.8468   1.911e-06       0.001      895  LS failed, Hessian reset
#      499       332.886    5.8432e-06       33.5207           1           1      921
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      527       332.886   4.79306e-08       33.0089      0.2565           1      962
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.97281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       69       340.351    0.00151677        36.055   3.272e-05       0.001      116  LS failed, Hessian reset
#       99       340.454   0.000104661         30.69      0.6867      0.6867      158
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      188       340.612    0.00120414       34.4398   3.533e-05       0.001      320  LS failed, Hessian reset
#      199        340.63   0.000128212       28.1658           1           1      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       340.662   2.86624e-05       30.9344      0.7809      0.7809      485
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      331       340.952    0.00343188       32.9357   8.206e-05       0.001      566  LS failed, Hessian reset
#      399       341.194   1.00173e-06       29.6126      0.2595      0.2595      661
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      419       341.194   8.86356e-06       27.9158    3.45e-07       0.001      724  LS failed, Hessian reset
#      442       341.194   7.97102e-09        34.831      0.1092      0.1092      760
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -7.69908
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       88        347.13    7.0879e-05       27.6456   2.791e-06       0.001      176  LS failed, Hessian reset
#       99       347.135   5.26264e-06       25.9894      0.1762      0.4989      190
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      139       347.138   3.14167e-05       24.3613   7.787e-07       0.001      276  LS failed, Hessian reset
#      199       347.141   6.67105e-07       35.3014      0.2209           1      366
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      266       347.224   0.000123234       34.6739   3.678e-06       0.001      481  LS failed, Hessian reset
#      299       347.228   1.08759e-06        36.292      0.6375           1      529
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      326       347.228   3.97167e-08       38.9012      0.2374      0.2374      566
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.8863
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       353.355   6.41909e-05       41.0578   1.714e-06       0.001      192  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       353.494   1.57767e-05       41.5641      0.8565      0.8565      323
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      293       353.506    1.1627e-05       40.1163   3.265e-07       0.001      474  LS failed, Hessian reset
#      299       353.506   1.60287e-06       30.9346      0.4758      0.4758      482
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      325       353.506   4.84211e-08       33.7658      0.2376           1      518
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.64049
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63       358.705   3.73741e-05       39.8224   9.158e-07       0.001      127  LS failed, Hessian reset
#       99       358.707   2.78102e-08       33.4535      0.2647           1      179
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      102       358.707   9.44211e-09       41.9327      0.2001      0.2001      182
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -7.07876
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       54       366.925   5.53188e-05       40.2307   1.265e-06       0.001      113  LS failed, Hessian reset
#       99       366.926    2.9176e-06       33.7794      0.8987      0.8987      164
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      115       366.934   0.000170703        39.686   4.245e-06       0.001      212  LS failed, Hessian reset
#      191       366.943   5.23517e-08       40.4247      0.3597      0.3597      309
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.66281
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       79       372.812    0.00177134       39.9156   4.903e-05       0.001      135  LS failed, Hessian reset
#       99       372.952   0.000324534       42.8754      0.5014      0.5014      157
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      163       373.094   0.000283742       30.0865   7.831e-06       0.001      273  LS failed, Hessian reset
#      199       373.108    1.3991e-05        53.132           1           1      319
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      292       373.338   0.000928471       37.8018   2.008e-05       0.001      465  LS failed, Hessian reset
#      299        373.39    0.00047652       29.3133      0.2552           1      474
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      332       373.412   7.40152e-05       40.0508   1.886e-06       0.001      559  LS failed, Hessian reset
#      399       373.417    2.4049e-06       36.5611           1           1      651
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      406       373.424    0.00012294       39.9604   3.235e-06       0.001      703  LS failed, Hessian reset
#      476       373.427   7.28713e-08       31.3913        1.72      0.4454      793
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.14731
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       377.943     0.0324665       50.8496           1           1      140
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      101       378.108    0.00284155       40.1175   5.413e-05       0.001      182  LS failed, Hessian reset
#      155       378.209   0.000509442       42.6618   1.287e-05       0.001      282  LS failed, Hessian reset
#      199       378.222   2.73168e-06       45.1509      0.4617   0.0004617      349
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      240       378.222   3.76323e-08       33.9672       0.305           1      399
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.14964
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       383.751    0.00332049       43.1508      0.2437           1      139
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       384.111   0.000809099       31.5191      0.4904      0.4904      276
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      206       384.151    0.00109891       29.9018   2.496e-05       0.001      370  LS failed, Hessian reset
#      253       384.217   0.000261084       43.9767   6.418e-06       0.001      469  LS failed, Hessian reset
#      299       384.224   1.20614e-05       30.0494           1           1      528
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      385       384.238   4.19264e-08       31.8893      0.2946           1      641
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.08587
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       391.091   6.96744e-05       25.9468      0.5156      0.5156      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      118       391.198    0.00107198        34.117   2.206e-05       0.001      192  LS failed, Hessian reset
#      176        391.23   8.28478e-06       32.3984   2.429e-07       0.001      304  LS failed, Hessian reset
#      196        391.23   8.75105e-08       32.2935      0.2359           1      333
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.69001
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        399.23    0.00654025       43.3531           1           1      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      108       399.302     0.0010398       50.2725   3.108e-05       0.001      187  LS failed, Hessian reset
#      199       399.359   3.37144e-06       33.7307      0.2593           1      312
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      212       399.371   0.000217417       40.3348   4.879e-06       0.001      369  LS failed, Hessian reset
#      273       399.375   1.36036e-08       29.4612      0.1595      0.6057      452
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.67056
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       74       407.323    0.00211651       42.7819   4.577e-05       0.001      151  LS failed, Hessian reset
#       99       407.432    0.00019572        36.897      0.3823      0.3823      179
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      152       407.614   0.000230963       28.7549   7.677e-06       0.001      301  LS failed, Hessian reset
#      199       407.623   8.12017e-05       37.8486           1           1      362
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      248       407.636   1.55209e-05       30.4414   5.059e-07       0.001      461  LS failed, Hessian reset
#      299       407.639   5.71079e-05       34.1776           1           1      525
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      303        407.64   3.66129e-06        42.626   1.626e-07       0.001      574  LS failed, Hessian reset
#      332       407.641   1.45413e-05       41.6382   3.913e-07       0.001      650  LS failed, Hessian reset
#      354       407.641   2.08842e-08       31.1693      0.1241      0.3603      690
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.32778
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       415.854   0.000281093       37.1108           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      110       415.929   0.000954494       40.4409   2.225e-05       0.001      185  LS failed, Hessian reset
#      194       415.957   5.14944e-06       44.5916    1.42e-07       0.001      332  LS failed, Hessian reset
#      199       415.957   8.97462e-07       31.6549      0.8432      0.8432      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      208       415.957   6.99815e-09       43.6499       0.114       0.114      348
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -6.25888
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       71       424.353     0.0020185       43.3759   5.595e-05       0.001      126  LS failed, Hessian reset
#       99       424.412   7.06673e-05       28.3157           1           1      167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       424.461   1.49094e-05        38.693           1           1      292
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       424.534   6.91828e-06       40.9195       0.187           1      422
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      329       424.534   1.29588e-07        35.901           1           1      461
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.1535
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       431.249    0.00977578       43.3498      0.7174      0.7174      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      122       431.567   0.000989645       44.8219   2.259e-05       0.001      204  LS failed, Hessian reset
#      159       431.619   8.95927e-05       22.0636   2.729e-06       0.001      284  LS failed, Hessian reset
#      199       431.622   7.23807e-06       37.9676       0.576       0.576      343
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      211       431.623   4.33912e-05        31.291   9.536e-07       0.001      393  LS failed, Hessian reset
#      266       431.626   9.89182e-06       29.0372   3.428e-07       0.001      520  LS failed, Hessian reset
#      299       431.627   6.37653e-07       31.8441      0.2797           1      568
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      307       431.627   4.14071e-08        39.496     0.07098           1      581
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.85663
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       439.789     0.0056724       31.5932      0.2576           1      134
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      104       439.815    0.00102963       25.6333   3.796e-05       0.001      174  LS failed, Hessian reset
#      199       439.877   4.09825e-05       44.7812           1           1      305
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      202       439.879   3.71285e-05       31.7619   1.035e-06       0.001      354  LS failed, Hessian reset
#      228       439.879   4.04469e-08       23.7486     0.08059           1      397
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.72073
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        447.33      0.019822        82.457       4.552      0.4552      150
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      105       447.655    0.00150604       44.3399   2.871e-05       0.001      196  LS failed, Hessian reset
#      146       447.985    9.7677e-05       37.5458   3.161e-06       0.001      284  LS failed, Hessian reset
#      199       447.996   1.84736e-05       26.1031   6.592e-07       0.001      388  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      231       447.997   1.87463e-06       36.7782   5.755e-08       0.001      461  LS failed, Hessian reset
#      242       447.997   3.80301e-08       32.4163      0.2083      0.8171      476
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -5.84339
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       457.141   0.000914515       23.3266      0.5004      0.5004      135
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      145        457.37   3.16499e-05       22.9793   1.162e-06       0.001      235  LS failed, Hessian reset
#      179       457.372   3.57192e-06       25.5603   1.066e-07       0.001      328  LS failed, Hessian reset
#      198       457.372   4.87952e-09       29.5316     0.04084     0.04084      361
# Optimization terminated normally:
#   Convergence detected: absolute parameter change was below tolerance
# Initial log joint probability = -6.75771
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       463.218    0.00955033       42.2491           1           1      131
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       463.534   6.19544e-05       33.6567        5.63       0.563      255
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      294       463.538   7.51273e-08       32.0957      0.7444      0.7444      385
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -14.3442
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       82       462.082   0.000102228       36.8199   3.005e-06       0.001      142  LS failed, Hessian reset
#       99       462.084   7.51299e-07       32.9148      0.4951      0.4951      167
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      144       462.084    1.7435e-06       44.9149   4.507e-08       0.001      273  LS failed, Hessian reset
#      164       462.084   1.89041e-07       36.6542   5.005e-09       0.001      337  LS failed, Hessian reset
#      166       462.084   2.71868e-08       34.4543      0.2497           1      340
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.83324
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       467.217    0.00120333       48.0637           1           1      127
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      104       467.238   0.000772732       37.7514   1.931e-05       0.001      178  LS failed, Hessian reset
#      156       467.289   2.85577e-05       35.0771   5.986e-07       0.001      278  LS failed, Hessian reset
#      199       467.289   1.00694e-07       51.0726      0.3288           1      333
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      205       467.289   2.44289e-08         40.46      0.2841           1      340
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.71692
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        471.75   0.000354194       41.1084      0.9045      0.9045      144
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      187       472.812   0.000544332       38.7172   1.293e-05       0.001      309  LS failed, Hessian reset
#      199       472.832   0.000185212       36.4252           1           1      326
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      227       472.877   0.000302447       41.6958   6.475e-06       0.001      397  LS failed, Hessian reset
#      298       472.892     9.395e-06       39.4212   2.473e-07       0.001      542  LS failed, Hessian reset
#      299       472.892   4.14714e-06       36.2988           1           1      543
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      338       472.893   5.49194e-08       35.1759        0.83      0.2375      597
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -6.40505
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        481.18    0.00517028       40.4302     0.09795           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      100       481.206    0.00244449       34.4177   6.046e-05       0.001      172  LS failed, Hessian reset
#      199        481.71   9.20248e-05       37.1885      0.3875      0.3875      293
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      269       481.779   0.000201588       42.7287   4.883e-06       0.001      436  LS failed, Hessian reset
#      299       481.783   1.38173e-07       33.1684      0.4877      0.4877      476
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      336       481.784   1.42401e-05       45.7407   3.351e-07       0.001      572  LS failed, Hessian reset
#      367       481.784   2.40951e-08       36.7283       0.149       0.149      609
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -10.2713
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       47       482.648    0.00607099       70.0482   0.0001628       0.001       97  LS failed, Hessian reset
#       87       483.421     0.0016278       34.3792   4.468e-05       0.001      180  LS failed, Hessian reset
#       99       483.536   0.000456001       28.9932           1           1      194
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      176       484.681   0.000711693        30.409   2.401e-05       0.001      323  LS failed, Hessian reset
#      199       484.735   7.16844e-05       30.0888      0.5039      0.5039      351
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      248       484.791   0.000212146       38.3376   5.682e-06       0.001      446  LS failed, Hessian reset
#      299         484.8   1.07159e-06       41.2598     0.03626     0.03626      519
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      353       484.804   4.14999e-07       36.6477   1.201e-08       0.001      631  LS failed, Hessian reset
#      363       484.804   4.05721e-08       28.8342     0.05783           1      646
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.05352
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       486.335    0.00172444       34.3416           1           1      133
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      103       486.475   0.000939541       29.7189   2.869e-05       0.001      170  LS failed, Hessian reset
#      164       486.783    0.00160149        44.081   3.853e-05       0.001      282  LS failed, Hessian reset
#      199       486.812   1.66146e-06       32.1817      0.4112      0.4112      334
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      232       486.812   1.41511e-06       34.3971   4.593e-08       0.001      414  LS failed, Hessian reset
#      245       486.812   5.11619e-08        34.514      0.2652           1      431
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -7.6568
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       75       494.958     0.0013573        39.297   3.053e-05       0.001      131  LS failed, Hessian reset
#       99       494.981   6.15229e-05       33.2847           1           1      165
# ...
#       99        858.68   1.05741e-05       37.2169      0.2532           1      138
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      174        859.06     0.0032733       106.561   6.438e-05       0.001      256  LS failed, Hessian reset
#      199       859.371   0.000575475       46.4646           1           1      288
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      267       859.481   0.000187893       38.7334   4.857e-06       0.001      433  LS failed, Hessian reset
#      299       859.488   1.78837e-07       36.6896      0.1585      0.4345      482
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      305       859.488   4.38107e-08       36.9552      0.2797      0.2797      489
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.21929
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       92       859.354   0.000898924        43.871   2.109e-05       0.001      174  LS failed, Hessian reset
#       99       859.422   0.000911678       44.0659           1           1      182
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      123       859.492   0.000717339       37.3112   1.457e-05       0.001      241  LS failed, Hessian reset
#      199       859.528   1.67974e-05       36.9278      0.7356      0.7356      335
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      262       859.532   1.71763e-07       40.0143      0.2305           1      415
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -10.5681
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       860.091   5.01785e-05       35.6942      0.4985      0.4985      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      157       860.097   2.33517e-07       43.6891    5.53e-09       0.001      242  LS failed, Hessian reset
#      159       860.097   2.79255e-08       35.2654      0.3965      0.3965      245
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -10.3353
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       859.961   0.000894217       69.6376   1.977e-05       0.001      187  LS failed, Hessian reset
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      199       860.016   1.93158e-05       41.3014      0.4808      0.4808      311
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      212       860.024   4.67477e-05        40.991   1.048e-06       0.001      373  LS failed, Hessian reset
#      283       860.038   1.25607e-07       34.4789           1           1      461
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -10.6061
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        856.54   0.000296085       34.5538           1           1      132
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      128       856.644   0.000626413       33.9248   1.595e-05       0.001      202  LS failed, Hessian reset
#      199       856.678   1.54684e-07        33.529      0.2421      0.8659      295
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      211       856.678   3.64794e-08       34.5749      0.2854     0.02854      312
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -12.0847
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63       854.355    0.00153363       36.2216   3.602e-05       0.001      114  LS failed, Hessian reset
#       99       854.415   1.03166e-06       38.5531      0.7295      0.7295      163
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      122       854.458   0.000236769       35.8908   8.484e-06       0.001      237  LS failed, Hessian reset
#      199       854.495    0.00026819       35.9968           1           1      328
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      216       854.559   0.000965325       51.7004   2.113e-05       0.001      415  LS failed, Hessian reset
#      237        854.62    0.00015827       43.3846   4.325e-06       0.001      471  LS failed, Hessian reset
#      273       854.626   2.62205e-06       38.2453   6.451e-08       0.001      555  LS failed, Hessian reset
#      286       854.626   3.92075e-08       32.6272      0.2958           1      573
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.3653
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       853.582   8.80277e-05        35.874           1           1      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      134       853.586   1.08392e-07       40.8841       0.289           1      178
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.77263
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       853.532   0.000454762       40.9065      0.5092      0.5092      123
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      137       853.586   0.000126695       41.7439   3.059e-06       0.001      215  LS failed, Hessian reset
#      183       853.657   0.000170811       35.7392   5.098e-06       0.001      321  LS failed, Hessian reset
#      199       853.681   0.000119723       33.6072      0.2317           1      341
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      250        853.69    2.1662e-05       47.7841   5.609e-07       0.001      472  LS failed, Hessian reset
#      286       853.694   4.30487e-06       35.3517   1.112e-07       0.001      548  LS failed, Hessian reset
#      299       853.694   2.80464e-07       35.1572      0.4267      0.4267      564
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      302       853.694   5.77464e-08       31.8324      0.3108           1      569
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -10.7663
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       854.604    0.00255372       40.7816      0.9846      0.9846      128
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      101       854.667    0.00191488       42.2739   5.299e-05       0.001      162  LS failed, Hessian reset
#      191       854.836   2.03787e-05       37.2016   5.519e-07       0.001      323  LS failed, Hessian reset
#      199       854.836   8.09992e-07       32.1973     0.06438           1      337
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      278       854.879   0.000860264       39.7115   1.435e-05       0.001      484  LS failed, Hessian reset
#      299       854.896   1.45714e-05       33.1143      0.3275           1      511
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      336       854.898   6.96436e-08        33.763      0.6923      0.6923      563
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.55092
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       63       856.049    0.00112431       54.2373   2.421e-05       0.001      112  LS failed, Hessian reset
#       99       856.337   0.000106851       28.9211           1           1      160
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      149       856.341   2.97195e-06       34.8358   7.063e-08       0.001      269  LS failed, Hessian reset
#      163       856.341   4.19898e-08       33.0884       0.462      0.1536      290
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.81521
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99        856.24   0.000181665       37.6744      0.4752      0.4752      130
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      112        856.41    0.00173322        33.771   4.047e-05       0.001      195  LS failed, Hessian reset
#      199       856.517    0.00065723       33.9274      0.3139      0.3139      303
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      222       856.524   2.02374e-05       38.0209   5.346e-07       0.001      377  LS failed, Hessian reset
#      254       856.525   8.14328e-08       34.6901      0.3964           1      420
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.87415
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       87       856.441    0.00171129       75.8222   3.269e-05       0.001      151  LS failed, Hessian reset
#       99       856.523   0.000178772       35.9768      0.2769           1      166
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      143       856.571   0.000442864       28.9521   9.514e-06       0.001      267  LS failed, Hessian reset
#      186       856.584   1.02601e-05       42.0682   2.767e-07       0.001      355  LS failed, Hessian reset
#      199       856.584   2.94353e-07       40.8299           1           1      376
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      201       856.584   4.41325e-08       33.2287      0.4115           1      380
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.63145
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       60       858.648   0.000861806       43.3249   1.799e-05       0.001      108  LS failed, Hessian reset
#       99       859.453   0.000341572       35.2521           1           1      155
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      154       859.685    0.00130499        33.995    3.56e-05       0.001      252  LS failed, Hessian reset
#      199       859.832   0.000651499       35.9495      0.2487           1      307
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      259       859.841   4.96834e-08       31.7332      0.1948           1      388
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -8.71359
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       861.822   7.91793e-05       36.5644      0.8305      0.8305      126
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      143       861.834   8.98142e-08       27.8227           1           1      189
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.63159
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       75       860.253    0.00150792       61.8117   3.317e-05       0.001      124  LS failed, Hessian reset
#       99       860.486   0.000279538       34.1664           1           1      156
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      194        860.81    0.00132874       39.1845   3.128e-05       0.001      306  LS failed, Hessian reset
#      199       860.853   0.000173149       29.0312      0.3843      0.3843      312
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      284       860.949   1.24928e-07       26.8201     0.08176           1      419
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -9.04992
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       859.478   0.000267987       32.7001       0.165      0.9079      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      175       860.403   0.000745595       30.3038   1.165e-05       0.001      253  LS failed, Hessian reset
#      199       860.494   0.000243367       39.0143           1           1      285
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      299       860.573    1.1032e-05       35.1107           1           1      412
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      399       860.582   9.74374e-07       38.0379      0.3935      0.3935      547
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      412       860.582   1.01946e-06       27.3769   2.384e-08       0.001      611  LS failed, Hessian reset
#      420       860.582    8.8038e-08       28.3354      0.6389      0.9782      622
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -17.6979
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       81       860.564    0.00170146       38.0534     5.4e-05       0.001      128  LS failed, Hessian reset
#       99       860.732    0.00148258       31.9848           1           1      154
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      167       860.932   1.34996e-05       29.4052   3.812e-07       0.001      296  LS failed, Hessian reset
#      199       860.933   7.96202e-06       39.3282     0.03547           1      340
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      251       860.935   2.95436e-07       33.4347      0.7962      0.7962      415
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance
# Initial log joint probability = -17.0691
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#       99       2183.92   0.000272047       38.1511           1           1      129
#     Iter      log prob        ||dx||      ||grad||       alpha      alpha0  # evals  Notes
#      173       2184.15   3.37023e-07       30.1992      0.3564           1      225
# Optimization terminated normally:
#   Convergence detected: relative gradient magnitude is below tolerance

# %%
## plot results
detected_anomalies = detect_anomalies(total_forecast)
plot_anomalies(detected_anomalies, mytitle="fbprophet Anomaly Detection")
# Out:
# alt.LayerChart(...)
